# %%
# Use below line for demo in external colabs
# !pip install -q torchdata==0.3.0 torchtext==0.12 spacy==3.2 altair GPUtil
# !python -m spacy download de_core_news_sm
# !python -m spacy download en_core_web_sm
# !pip install -q git+https://github.com/nikitakapitan/transformers.git

# %%
import warnings
warnings.filterwarnings('ignore')

from transformers.data.token import load_tokenizers
from transformers.data.vocab import load_vocab

from transformers.output import run_model_example

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
spacy_de, spacy_en = load_tokenizers()
vocab_src, vocab_tgt = load_vocab(spacy_de=spacy_de, spacy_en=spacy_en)
# Out:
# Finished.
# Vocabulary sizes:
# len: SRC=8315 TGT=6384

# %%
run_model_example(vocab_src, vocab_tgt, spacy_de, spacy_en, n_examples=1)
None
# Out:
# Preparing Data...
# Loading Trained Model...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 run_model_example(vocab_src, vocab_tgt, spacy_de, spacy_en, n_examples=1)
#       2 None
#
# File ~/GitHub/transformers/src/transformers/output.py:61, in run_model_example(vocab_src, vocab_tgt, spacy_de, spacy_en, n_examples)
#      58 print("Loading Trained Model...")
#      60 model = make_model(len(vocab_src), len(vocab_tgt), N=6)
# ---> 61 model.load_state_dict(
#      62     torch.load("multi30k_model_final.pt", map_location=torch.device("cpu"))
#      63 )
#      65 print("checking Model Outputs:")
#      66 example_data = check_outputs(valid_dataloader, model, vocab_src, vocab_tgt, n_examples=n_examples)
#
# File ~/GitHub/venvai/lib/python3.10/site-packages/torch/nn/modules/module.py:1497, in Module.load_state_dict(self, state_dict, strict)
#    1492         error_msgs.insert(
#    1493             0, 'Missing key(s) in state_dict: {}. '.format(
#    1494                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1496 if len(error_msgs) > 0:
# -> 1497     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1498                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1499 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for EncoderDecoder:
# 	Missing key(s) in state_dict: "encoder.layers.0.self_attn.q_fc.weight", "encoder.layers.0.self_attn.q_fc.bias", "encoder.layers.0.self_attn.k_fc.weight", "encoder.layers.0.self_attn.k_fc.bias", "encoder.layers.0.self_attn.v_fc.weight", "encoder.layers.0.self_attn.v_fc.bias", "encoder.layers.0.self_attn.final_fc.weight", "encoder.layers.0.self_attn.final_fc.bias", "encoder.layers.0.feed_fwd.w_1.weight", "encoder.layers.0.feed_fwd.w_1.bias", "encoder.layers.0.feed_fwd.w_2.weight", "encoder.layers.0.feed_fwd.w_2.bias", "encoder.layers.0.resconnect.0.norm.a_2", "encoder.layers.0.resconnect.0.norm.b_2", "encoder.layers.0.resconnect.1.norm.a_2", "encoder.layers.0.resconnect.1.norm.b_2", "encoder.layers.0.norm.a_2", "encoder.layers.0.norm.b_2", "encoder.layers.1.self_attn.q_fc.weight", "encoder.layers.1.self_attn.q_fc.bias", "encoder.layers.1.self_attn.k_fc.weight", "encoder.layers.1.self_attn.k_fc.bias", "encoder.layers.1.self_attn.v_fc.weight", "encoder.layers.1.self_attn.v_fc.bias", "encoder.layers.1.self_attn.final_fc.weight", "encoder.layers.1.self_attn.final_fc.bias", "encoder.layers.1.feed_fwd.w_1.weight", "encoder.layers.1.feed_fwd.w_1.bias", "encoder.layers.1.feed_fwd.w_2.weight", "encoder.layers.1.feed_fwd.w_2.bias", "encoder.layers.1.resconnect.0.norm.a_2", "encoder.layers.1.resconnect.0.norm.b_2", "encoder.layers.1.resconnect.1.norm.a_2", "encoder.layers.1.resconnect.1.norm.b_2", "encoder.layers.1.norm.a_2", "encoder.layers.1.norm.b_2", "encoder.layers.2.self_attn.q_fc.weight", "encoder.layers.2.self_attn.q_fc.bias", "encoder.layers.2.self_attn.k_fc.weight", "encoder.layers.2.self_attn.k_fc.bias", "encoder.layers.2.self_attn.v_fc.weight", "encoder.layers.2.self_attn.v_fc.bias", "encoder.layers.2.self_attn.final_fc.weight", "encoder.layers.2.self_attn.final_fc.bias", "encoder.layers.2.feed_fwd.w_1.weight", "encoder.layers.2.feed_fwd.w_1.bias", "encoder.layers.2.feed_fwd.w_2.weight", "encoder.layers.2.feed_fwd.w_2.bias", "encoder.layers.2.resconnect.0.norm.a_2", "encoder.layers.2.resconnect.0.norm.b_2", "encoder.layers.2.resconnect.1.norm.a_2", "encoder.layers.2.resconnect.1.norm.b_2", "encoder.layers.2.norm.a_2", "encoder.layers.2.norm.b_2", "encoder.layers.3.self_attn.q_fc.weight", "encoder.layers.3.self_attn.q_fc.bias", "encoder.layers.3.self_attn.k_fc.weight", "encoder.layers.3.self_attn.k_fc.bias", "encoder.layers.3.self_attn.v_fc.weight", "encoder.layers.3.self_attn.v_fc.bias", "encoder.layers.3.self_attn.final_fc.weight", "encoder.layers.3.self_attn.final_fc.bias", "encoder.layers.3.feed_fwd.w_1.weight", "encoder.layers.3.feed_fwd.w_1.bias", "encoder.layers.3.feed_fwd.w_2.weight", "encoder.layers.3.feed_fwd.w_2.bias", "encoder.layers.3.resconnect.0.norm.a_2", "encoder.layers.3.resconnect.0.norm.b_2", "encoder.layers.3.resconnect.1.norm.a_2", "encoder.layers.3.resconnect.1.norm.b_2", "encoder.layers.3.norm.a_2", "encoder.layers.3.norm.b_2", "encoder.layers.4.self_attn.q_fc.weight", "encoder.layers.4.self_attn.q_fc.bias", "encoder.layers.4.self_attn.k_fc.weight", "encoder.layers.4.self_attn.k_fc.bias", "encoder.layers.4.self_attn.v_fc.weight", "encoder.layers.4.self_attn.v_fc.bias", "encoder.layers.4.self_attn.final_fc.weight", "encoder.layers.4.self_attn.final_fc.bias", "encoder.layers.4.feed_fwd.w_1.weight", "encoder.layers.4.feed_fwd.w_1.bias", "encoder.layers.4.feed_fwd.w_2.weight", "encoder.layers.4.feed_fwd.w_2.bias", "encoder.layers.4.resconnect.0.norm.a_2", "encoder.layers.4.resconnect.0.norm.b_2", "encoder.layers.4.resconnect.1.norm.a_2", "encoder.layers.4.resconnect.1.norm.b_2", "encoder.layers.4.norm.a_2", "encoder.layers.4.norm.b_2", "encoder.layers.5.self_attn.q_fc.weight", "encoder.layers.5.self_attn.q_fc.bias", "encoder.layers.5.self_attn.k_fc.weight", "encoder.layers.5.self_attn.k_fc.bias", "encoder.layers.5.self_attn.v_fc.weight", "encoder.layers.5.self_attn.v_fc.bias", "encoder.layers.5.self_attn.final_fc.weight", "encoder.layers.5.self_attn.final_fc.bias", "encoder.layers.5.feed_fwd.w_1.weight", "en ...
# 	Unexpected key(s) in state_dict: "src_embed.0.lut.weight", "src_embed.1.pe", "tgt_embed.0.lut.weight", "tgt_embed.1.pe", "encoder.layers.0.feed_forward.w_1.weight", "encoder.layers.0.feed_forward.w_1.bias", "encoder.layers.0.feed_forward.w_2.weight", "encoder.layers.0.feed_forward.w_2.bias", "encoder.layers.0.sublayer.0.norm.a_2", "encoder.layers.0.sublayer.0.norm.b_2", "encoder.layers.0.sublayer.1.norm.a_2", "encoder.layers.0.sublayer.1.norm.b_2", "encoder.layers.0.self_attn.linears.0.weight", "encoder.layers.0.self_attn.linears.0.bias", "encoder.layers.0.self_attn.linears.1.weight", "encoder.layers.0.self_attn.linears.1.bias", "encoder.layers.0.self_attn.linears.2.weight", "encoder.layers.0.self_attn.linears.2.bias", "encoder.layers.0.self_attn.linears.3.weight", "encoder.layers.0.self_attn.linears.3.bias", "encoder.layers.1.feed_forward.w_1.weight", "encoder.layers.1.feed_forward.w_1.bias", "encoder.layers.1.feed_forward.w_2.weight", "encoder.layers.1.feed_forward.w_2.bias", "encoder.layers.1.sublayer.0.norm.a_2", "encoder.layers.1.sublayer.0.norm.b_2", "encoder.layers.1.sublayer.1.norm.a_2", "encoder.layers.1.sublayer.1.norm.b_2", "encoder.layers.1.self_attn.linears.0.weight", "encoder.layers.1.self_attn.linears.0.bias", "encoder.layers.1.self_attn.linears.1.weight", "encoder.layers.1.self_attn.linears.1.bias", "encoder.layers.1.self_attn.linears.2.weight", "encoder.layers.1.self_attn.linears.2.bias", "encoder.layers.1.self_attn.linears.3.weight", "encoder.layers.1.self_attn.linears.3.bias", "encoder.layers.2.feed_forward.w_1.weight", "encoder.layers.2.feed_forward.w_1.bias", "encoder.layers.2.feed_forward.w_2.weight", "encoder.layers.2.feed_forward.w_2.bias", "encoder.layers.2.sublayer.0.norm.a_2", "encoder.layers.2.sublayer.0.norm.b_2", "encoder.layers.2.sublayer.1.norm.a_2", "encoder.layers.2.sublayer.1.norm.b_2", "encoder.layers.2.self_attn.linears.0.weight", "encoder.layers.2.self_attn.linears.0.bias", "encoder.layers.2.self_attn.linears.1.weight", "encoder.layers.2.self_attn.linears.1.bias", "encoder.layers.2.self_attn.linears.2.weight", "encoder.layers.2.self_attn.linears.2.bias", "encoder.layers.2.self_attn.linears.3.weight", "encoder.layers.2.self_attn.linears.3.bias", "encoder.layers.3.feed_forward.w_1.weight", "encoder.layers.3.feed_forward.w_1.bias", "encoder.layers.3.feed_forward.w_2.weight", "encoder.layers.3.feed_forward.w_2.bias", "encoder.layers.3.sublayer.0.norm.a_2", "encoder.layers.3.sublayer.0.norm.b_2", "encoder.layers.3.sublayer.1.norm.a_2", "encoder.layers.3.sublayer.1.norm.b_2", "encoder.layers.3.self_attn.linears.0.weight", "encoder.layers.3.self_attn.linears.0.bias", "encoder.layers.3.self_attn.linears.1.weight", "encoder.layers.3.self_attn.linears.1.bias", "encoder.layers.3.self_attn.linears.2.weight", "encoder.layers.3.self_attn.linears.2.bias", "encoder.layers.3.self_attn.linears.3.weight", "encoder.layers.3.self_attn.linears.3.bias", "encoder.layers.4.feed_forward.w_1.weight", "encoder.layers.4.feed_forward.w_1.bias", "encoder.layers.4.feed_forward.w_2.weight", "encoder.layers.4.feed_forward.w_2.bias", "encoder.layers.4.sublayer.0.norm.a_2", "encoder.layers.4.sublayer.0.norm.b_2", "encoder.layers.4.sublayer.1.norm.a_2", "encoder.layers.4.sublayer.1.norm.b_2", "encoder.layers.4.self_attn.linears.0.weight", "encoder.layers.4.self_attn.linears.0.bias", "encoder.layers.4.self_attn.linears.1.weight", "encoder.layers.4.self_attn.linears.1.bias", "encoder.layers.4.self_attn.linears.2.weight", "encoder.layers.4.self_attn.linears.2.bias", "encoder.layers.4.self_attn.linears.3.weight", "encoder.layers.4.self_attn.linears.3.bias", "encoder.layers.5.feed_forward.w_1.weight", "encoder.layers.5.feed_forward.w_1.bias", "encoder.layers.5.feed_forward.w_2.weight", "encoder.layers.5.feed_forward.w_2.bias", "encoder.layers.5.sublayer.0.norm.a_2", "encoder.layers.5.sublayer.0.norm.b_2", "encoder.layers.5.sublayer.1.norm.a_2", "encoder.layers.5.sublayer.1.norm.b_2", "encoder.layers.5.self_attn.linears.0.weight", ...

# %%
import torch
# nik = torch.load('multi30k_model_final.pt')

# %%
model = torch.jit.load('multi30k_model_final.pt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 model = torch.jit.load('multi30k_model_final.pt')
#
# File ~/GitHub/venvai/lib/python3.10/site-packages/torch/jit/_serialization.py:162, in load(f, map_location, _extra_files)
#     160 cu = torch._C.CompilationUnit()
#     161 if isinstance(f, str) or isinstance(f, pathlib.Path):
# --> 162     cpp_module = torch._C.import_ir_module(cu, str(f), map_location, _extra_files)
#     163 else:
#     164     cpp_module = torch._C.import_ir_module_from_buffer(
#     165         cu, f.read(), map_location, _extra_files
#     166     )
#
# RuntimeError: PytorchStreamReader failed locating file constants.pkl: file not found

# %%
for param in nik.parameters():
    print(param)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 for param in nik.parameters():
#       2     print(param)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'parameters'
